# %%
# Importing Required Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("dark_background")

# %%
# Importing Data/File from Google Drive Using read_csv And Review it Using head()

df = pd.read_csv("/content/drive/MyDrive/DEEP LEARNING/laptop_data.csv")
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df["Ram"].unique()
# Out:
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '6GB', '32GB', '24GB', '64GB'],
#       dtype=object)

# %%
# Checking shape of Data

df.shape
# Out:
# (1303, 12)

# %%
# See some Information(dtypes,all columns name,No. of not null values ) about Data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
# Checking Is there Any NaN values present in Data or not

df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# Check is there any Duplicate Data present or not

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Some Numerical Anlysis(Mean,STD,Percentile(25th,50th,75th),Max) about the Data

df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
# What are the columns present in Data

df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
# Data Cleaning
# Drop Unwanted  Columns

df = df.drop(columns=['Unnamed: 0'])

# %%
# Replace Some unwanted Value from Data Like 8GB remove GB

df["Ram"] = df["Ram"].str.replace('GB','')
df["Weight"] = df["Weight"].str.replace('kg','')

# %%
# head()

df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
# Memory Storage Free

df["Ram"] = df["Ram"].astype("int32")
df["Weight"] = df["Weight"].astype("float32")

# %%
# Univariate Analysis
# Understand information of specific columns("Company")

df["Company"].sample(5)
# Out:
# 351        HP
# 543      Acer
# 203    Lenovo
# 301      Asus
# 739      Acer
# Name: Company, dtype: object

# %%
# Find All the Unique Laptop's Company Presnt in Data Using Bar Chart

df["Company"].value_counts().plot(kind = 'bar',color='green')
plt.ylabel("Total Count")
# Out:
# Text(0, 0.5, 'Total Count')

# %%
# Understand information of specific columns("TypeName")

df["TypeName"].sample(6)
# Out:
# 1258              Notebook
# 219     2 in 1 Convertible
# 791               Notebook
# 562              Ultrabook
# 201               Notebook
# 275               Notebook
# Name: TypeName, dtype: object

# %%
# Find All the Unique usage Categories of Laptop's Presnt in Data Using pie Chart


df["TypeName"].value_counts().plot(kind = 'pie',autopct = '%.2f',cmap = 'viridis')
# Out:
# <Axes: ylabel='count'>

# %%
# See the Data Distribution of 'Inches' columns using KDE Plot
# Multi-modal Distribution

sns.kdeplot(data = df,x = 'Inches',fill = True,color ='green',alpha = 1 )
# Out:
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
# Find the no. of Unique Ram Size in Data Using Bar Chart

df["Ram"].value_counts().plot(kind ="bar" )
plt.ylabel("Total Count")
# Out:
# <Axes: xlabel='Ram'>

# %%
# See the Data Distribution of Output Columns ('Price') using KDE Plot

sns.kdeplot(data=df, x='Price', fill=True, color='deeppink', alpha=0.8)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# Bivariate Analysis
# Compare the average laptop price across different companies
# Razer has the highest average laptop price according to the dataset

sns.barplot(data = df,x = "Company",y = "Price",hue = "Company",palette = "viridis",legend = False)
plt.xticks(rotation = 90)
plt.show()

# %%
# Validate Using Data

print(df[df["Company"] == 'Razer'][["Company","Ram",'Price']])
print()
print("Average Price - ",round(df[df["Company"] == 'Razer']["Price"].mean(),2))
# Out:
#      Company  Ram      Price
# 196    Razer   32  324954.72
# 647    Razer   16  138474.72
# 778    Razer   16  154458.72
# 816    Razer   16   95850.72
# 830    Razer   32  292986.72
# 1117   Razer    8   54825.12
# 1231   Razer   16  186426.72
#
# Average Price -  178282.49

# %%
# Compare the average laptop price across different Types of Laptop
# Workstation has the highest average laptop price according to the dataset

sns.barplot(data = df,x = "TypeName",y = "Price",hue = "TypeName",palette = "viridis",legend = False)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
# Compare laptop price with laptop screen size
# We can observe a slight positive relationship between Inches and Price

plt.scatter(df["Inches"],df["Price"])
plt.xlabel("Inches")
plt.ylabel("Price")
plt.show()

# %%
# Extract hidden information from ScreenResolution
# Create a new feature indicating whether the laptop has a touchscreen

df["Touchscreen"] = df["ScreenResolution"].apply(lambda x : 1 if "Touchscreen" in x else 0)

# %%
# Univariate Analysis
# Find the proportion of touchscreen and non-touchscreen laptops
# Almost 15% of laptops in the dataset are touchscreen

df["Touchscreen"].value_counts().plot(kind = 'pie',labels =["Not Touchscreen",'Touchscreen'],cmap = 'viridis',autopct = "%.2f%%")
plt.ylabel("")
plt.show()

# %%
# Compare the average laptop price between TouchScreen And Not TouchScreen
# Touchscreen laptops have a higher average price than non-touchscreen laptops in this dataset.

sns.barplot(data = df,x = "Touchscreen",y ="Price",palette = 'viridis',hue ='Touchscreen',legend = False )
plt.xticks([0,1],["Not TouchScreen",'TouchScreen'])
plt.xlabel("Laptop Type")
plt.ylabel("Avg. Price")
plt.show()

# %%
# Extract hidden information from ScreenResolution
# Create a new feature indicating whether the laptop has an IPS display
# IPS = In-Plane Switching, a type of LCD display panel technology

df["IPS"] = df["ScreenResolution"].apply(lambda x : 1 if 'IPS' in x else 0 )

# %%
# Univariate Analysis
# See That almost 72% laptop's doesn't have IPS

print((df["IPS"].value_counts()[0]/df.shape[0])*100)

df["IPS"].value_counts().sort_index().plot(kind = 'bar',cmap = 'viridis')
plt.xticks([0,1],["Not IPS",'IPS'],rotation = 0)
plt.xlabel("IPS")
plt.ylabel("Total Count")
# Out:
# np.float64(71.98772064466615)

# %%
# Bivariate Analysis
# Compare the average laptop price between laptops with IPS and non-IPS displays
# Laptops with IPS displays have a higher average price than laptops without IPS displays

sns.barplot(data = df,x="IPS", y="Price", hue="IPS", palette="magma", legend=False)
plt.xticks([0,1],["Not IPS",'IPS'],rotation = 0)
plt.xlabel("IPS Display")
plt.ylabel("AVG. Price")
plt.show()

# %%
# Review "ScreenResolution" column

df["ScreenResolution"]
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
# We split the "ScreenResolution" column one time on the basis of 'x' delimiter and store it into 2 column by expand =True

new = df["ScreenResolution"].str.split('x',n=1,expand = True)

# %%
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
# We create"X_res" and store 1st column of new and and store 2nd in "Y_res"

df["X_res"] = new[0]
df["Y_res"] = new[1]

# %%
# Using logical expression we extract the actual number and pick up from list

df["X_res"] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x: x[0])

# %%
print(df["X_res"].info())
df["Y_res"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1303 entries, 0 to 1302
# Series name: X_res
# Non-Null Count  Dtype
# --------------  -----
# 1303 non-null   object
# dtypes: object(1)
# memory usage: 10.3+ KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 1303 entries, 0 to 1302
# Series name: Y_res
# Non-Null Count  Dtype
# --------------  -----
# 1303 non-null   object
# dtypes: object(1)
# memory usage: 10.3+ KB

# %%
# We convert both column into interger format

df["X_res"] = df["X_res"].astype("int32")
df["Y_res"] = df["Y_res"].astype("int32")

# %%
# we find out correlation between "X_res","Y_res" and "price"
# There is Strong Positive correlation between these three columns

df.select_dtypes(include=['number']).corr()['Price']
# Out:
# Inches    0.068197
# Ram       0.743007
# Weight    0.210370
# Price     1.000000
# X_res     0.556529
# Y_res     0.552809
# Name: Price, dtype: float64

# %%
# We extract a new column PPI(pixel per inches)

df["PPI"] = (((df["X_res"] **2) + (df["Y_res"] ** 2))**0.5)/df["Inches"]

# %%
# drop three  "ScreenResolution",'X_res',"Y_res" columns

df.drop(columns = ["ScreenResolution",'X_res',"Y_res"],inplace = True)

# %%
# # drop "Inches" columns

df = df.drop(columns = ["Inches"])

# %%
# We find out no. of unique values present in cpu column

df["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
# split the "Cpu" colums and extract first three values then using " " join them and store in "Cpu Name"

df["Cpu Name"] = df["Cpu"].apply(lambda x : " ".join( x.split()[0:3]))

# %%
df["Cpu Name"].value_counts()
# Out:
# Cpu Name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# AMD A9-Series 9410            3
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD E-Series E2-9000e         2
# AMD A10-Series A10-9620P      2
# AMD A6-Series A6-9220         2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1505M           2
# Intel Xeon E3-1535M           2
# Intel Atom X5-Z8350           2
# Intel Atom x5-Z8300           1
# AMD E-Series 6110             1
# AMD E-Series 9000e            1
# ...

# %%
# In this function we create the five categories in cpu column

def Fetch_Processor(text):
  if text == "Intel Core i7" or text == "Intel Core i5" or text == "Intel Core i3":
    return text
  else :
    if text.split()[0] == "Intel":
      return "Other Intel Processor"
    else:
      return 'AMD Processor'

# %%
# apply function in "Cpu Name" and store it in "Cpu Brands"

df["Cpu Brands"] = df["Cpu Name"].apply(Fetch_Processor)

# %%
# Most of the cpu brannds from "Intel Core i7" and "Intel Core i5"


df['Cpu Brands'].value_counts().plot(kind='bar',color = 'deeppink')
# Out:
# <Axes: xlabel='Cpu Brands'>

# %%
# Compare the average laptop price across different cpu brands
# "Intel Core i7" has the highest average laptop price according to the dataset

sns.barplot(x = df["Cpu Brands"],y = df["Price"])
plt.xticks(rotation =90)
plt.show()

# %%
df.sample()
# Out:
#    Company  TypeName  Inches                       Cpu  Ram     Memory  \
# 66      HP  Notebook    15.6  Intel Core i3 6006U 2GHz    4  500GB HDD
#
#                Gpu       OpSys  Weight       Price  Touchscreen  IPS  \
# 66  AMD Radeon 520  Windows 10    1.86  23373.4032            0    0
#
#           PPI       Cpu Name     Cpu Brands
# 66  100.45467  Intel Core i3  Intel Core i3

# %%
df = df.drop(columns = ["Cpu","Cpu Name"])

# %%
# Compare the average laptop price across different Ram size
# We find A Interesting point i.e There is less price difference between 4,6 and 8,12 and 16,24 and 32,64

sns.barplot(x = df["Ram"], y = df["Price"],color = "yellow")
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df["Memory"].value_counts()
# Out:
# Memory
# 256 SSD                         412
# 1000 HDD                        224
# 500 HDD                         132
# 512 SSD                         118
# 128 SSD +  1000 HDD              94
# 128 SSD                          76
# 256 SSD +  1000 HDD              73
# 32 Flash Storage                 38
# 2000 HDD                         16
# 64 Flash Storage                 15
# 512 SSD +  1000 HDD              14
# 1000 SSD                         14
# 256 SSD +  2000 HDD              10
# 1000 Hybrid                       9
# 256 Flash Storage                 8
# 16 Flash Storage                  7
# 32 SSD                            6
# 180 SSD                           5
# 128 Flash Storage                 4
# 512 SSD +  2000 HDD               3
# 16 SSD                            3
# 256 SSD +  256 SSD                2
# 512 Flash Storage                 2
# 1000 SSD +  1000 HDD              2
# 256 SSD +  500 HDD                2
# 128 SSD +  2000 HDD               2
# ...

# %%
df["Memory"] = df["Memory"].astype(str).replace(r'\.0','',regex = True)
#df["Memory"] = df["Memory"].astype(int).astype(str)

df["Memory"] = df["Memory"].str.replace("GB",'')
df["Memory"] = df["Memory"].str.replace("TB",'000')
new = df["Memory"].str.split('+',n=1,expand = True)
df["First"] = new[0]
df["First"] = df["First"].str.strip()

df["Second"] = new[1]

df["Layer1HDD"] = df["First"].apply(lambda x : 1 if 'HDD' in x else 0)
df["Layer1SSD"] = df["First"].apply(lambda x : 1 if 'SSD' in x else 0)
df["Layer1Hybrid"] = df["First"].apply(lambda x : 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["First"].apply(lambda x : 1 if "Flash Storage" in x else 0)

# Ensure the column is string type, remove non-digits, and replace empty strings with '0'
df["First"] = df['First'].astype(str).str.replace(r'\D','',regex = True)
df["First"] = df["First"].replace('', '0') # Replace empty strings that might result from str.replace

df["Second"] = df["Second"].fillna("0")

df["Layer2HDD"] = df["Second"].apply(lambda x : 1 if 'HDD' in x else 0)
df["Layer2SSD"] = df["Second"].apply(lambda x : 1 if 'SSD' in x else 0)
df["Layer2Hybrid"] = df["Second"].apply(lambda x : 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["Second"].apply(lambda x : 1 if "Flash Storage" in x else 0)

# Ensure the column is string type, remove non-digits, and replace empty strings with '0'
df["Second"] = df['Second'].astype(str).str.replace(r'\D','',regex = True)
df["Second"] = df["Second"].replace('', '0') # Replace empty strings that might result from str.replace

df["First"] = df["First"].astype(int)
df["Second"] = df["Second"].astype(int)

df["HDD"] = (df["First"] * df["Layer1HDD"] + df["Second"] * df["Layer2HDD"])
df["SSD"] = (df["First"] * df["Layer1SSD"] + df["Second"] * df["Layer2SSD"])
df["Hybrid"] = (df["First"] * df["Layer1Hybrid"] + df["Second"] * df["Layer2Hybrid"])
df["Flash Storage"] = (df["First"] * df["Layer1Flash_Storage"] + df["Second"] * df["Layer2Flash_Storage"])

df.drop(columns = ['First','Second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage',
                   'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'],inplace = True)

# %%
df.sample()
# Out:
#     Company            TypeName  Inches  Ram            Memory  \
# 560    Acer  2 in 1 Convertible    11.6    4  32 Flash Storage
#
#                        Gpu       OpSys  Weight     Price  Touchscreen  IPS  \
# 560  Intel HD Graphics 500  Windows 10    1.25  18594.72            1    1
#
#             PPI             Cpu Brands  HDD  SSD  Hybrid  Flash Storage
# 560  189.905791  Other Intel Processor    0    0       0             32

# %%
# Drop column
df = df.drop(columns = ["Memory"])

# %%
df.sample()
# Out:
#     Company  TypeName  Ram                     Gpu       OpSys  Weight  \
# 223      HP  Notebook    8  Intel UHD Graphics 620  Windows 10     2.1
#
#         Price  Touchscreen  IPS         PPI     Cpu Brands   HDD  SSD  Hybrid  \
# 223  42304.32            0    0  141.211998  Intel Core i5  1000    0       0
#
#      Flash Storage
# 223              0

# %%
df.select_dtypes(include = ['number']).corr()["Price"]
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash Storage   -0.040511
# Name: Price, dtype: float64

# %%
# Drop columns "Hybrid","Flash Storage" because it has negative and less correlation with price
df = df.drop(columns = ["Hybrid","Flash Storage"])

# %%
df.sample()
# Out:
#     Company  TypeName  Ram                    Gpu       OpSys  Weight  \
# 660    Dell  Notebook    8  Intel HD Graphics 520  Windows 10    1.56
#
#         Price  Touchscreen  IPS         PPI     Cpu Brands  HDD  SSD
# 660  65481.12            0    0  157.350512  Intel Core i5    0  256

# %%
df["Gpu"]
# Out:
# 0       Intel Iris Plus Graphics 640
# 1             Intel HD Graphics 6000
# 2              Intel HD Graphics 620
# 3                 AMD Radeon Pro 455
# 4       Intel Iris Plus Graphics 650
#                     ...
# 1298           Intel HD Graphics 520
# 1299           Intel HD Graphics 520
# 1300               Intel HD Graphics
# 1301              AMD Radeon R5 M330
# 1302               Intel HD Graphics
# Name: Gpu, Length: 1303, dtype: object

# %%
df["Gpu"].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
# split column and fetch the first value
df["Gpu Brand"] = df["Gpu"].apply(lambda x : x.split()[0])

# %%
df.sample()
# Out:
#     Company  TypeName  Inches  Ram                    Gpu       OpSys  Weight  \
# 765    Acer  Notebook    13.3    4  Intel HD Graphics 520  Windows 10     1.6
#
#        Price  Touchscreen  IPS        PPI     Cpu Brands  HDD  SSD Gpu Brand
# 765  34898.4            0    0  117.82653  Intel Core i5    0  128     Intel

# %%
df["Gpu Brand"].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gpu Brand'>

# %%
# Remove the ARM brand because it has less count
df = df[~(df["Gpu Brand"] == 'ARM')]

# %%
df.sample()
# Out:
#     Company   TypeName  Ram                   Gpu       OpSys  Weight  \
# 103      HP  Ultrabook    8  Nvidia GeForce MX150  Windows 10    1.38
#
#         Price  Touchscreen  IPS         PPI     Cpu Brands  HDD  SSD Gpu Brand
# 103  59620.32            0    1  165.632118  Intel Core i7    0  256    Nvidia

# %%
df["Gpu Brand"].value_counts().plot(kind = 'bar',color= 'blue')
# Out:
# <Axes: xlabel='Gpu Brand'>

# %%
# Compare the average laptop price across different Gpu brands
# "Nvidia" has the highest average laptop price according to the dataset

sns.barplot(x = df["Gpu Brand"],y = df["Price"],estimator = 'median',hue = df["Gpu Brand"],palette = "viridis")
plt.show()

# %%
df.select_dtypes(include = ["number"]).corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# PPI            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
df.sample()
# Out:
#      Company  TypeName  Ram                   Gpu       OpSys  Weight  \
# 1208    Acer  Notebook    8  Nvidia GeForce 940MX  Windows 10     3.3
#
#          Price  Touchscreen  IPS         PPI     Cpu Brands   HDD  SSD  \
# 1208  33513.12            0    0  106.113062  Intel Core i3  1000    0
#
#      Gpu Brand
# 1208    Nvidia

# %%
# drop column
df=df.drop(columns = ["Gpu"])

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI     Cpu Brands  HDD  SSD Gpu Brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
# function for fetching different opsys
def fetch_Os(inp) :
  if inp == "Windows 10" or inp == "Windows 7" or inp == "Windows 10 S" :
    return "Windows"
  elif inp == "macOS" or inp == "Mac OS X":
    return "Mac"
  else :
    return "Others/Linux/No Os"

# %%
# apply it and store on "Os" column
df["Os"] = df["OpSys"].apply(fetch_Os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI     Cpu Brands  HDD  SSD Gpu Brand                  Os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/Linux/No Os
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df = df.drop(columns = ["OpSys"])

# %%
df.sample(3)
# Out:
#     Company  TypeName  Ram  Weight     Price  Touchscreen  IPS         PPI  \
# 708  Lenovo  Notebook    8    1.80  63456.48            0    0  157.350512
# 363      HP  Notebook    8    1.86  34045.92            0    0  141.211998
# 184  Xiaomi  Notebook    8    1.95  63882.72            0    1  141.211998
#
#         Cpu Brands   HDD  SSD Gpu Brand                  Os
# 708  Intel Core i5     0  256     Intel             Windows
# 363  Intel Core i5  1000    0     Intel             Windows
# 184  Intel Core i5     0  256    Nvidia  Others/Linux/No Os

# %%
df["Os"].value_counts().plot(kind = 'bar' )
# Out:
# <Axes: xlabel='Os'>

# %%
# Compare the average laptop price across different Os brands
# "Mac" has the highest average laptop price according to the dataset which is obvious

sns.barplot(x = df["Os"], y = df["Price"])
# Out:
# <Axes: xlabel='Os', ylabel='Price'>

# %%
sns.displot(df["Weight"], kind='kde', fill=True, color='deeppink', alpha=0.8)

# %%
# We can see very less postive correlation between Weight and Price
sns.scatterplot(x = df["Weight"], y = df["Price"])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df["Weight"].corr(df["Price"])
# Out:
# np.float64(0.20986692455314307)

# %%
sns.heatmap(df.select_dtypes(include = ["number"]).corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %%
sns.displot(np.log(df["Price"]),kind = 'kde',fill = True,color = 'yellow')

# %%
# split the dataset and apply log transform on output variable
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X.sample(3)
# Out:
#      Company  TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 134       HP  Notebook    8    2.05            0    0  100.454670
# 189     Dell  Notebook    8    2.80            0    0  127.335675
# 1218  Lenovo    Gaming    8    2.60            0    1  141.211998
#
#          Cpu Brands   HDD  SSD Gpu Brand       Os
# 134   Intel Core i7  1000    0     Intel  Windows
# 189   Intel Core i7  1000  128       AMD  Windows
# 1218  Intel Core i7  1000  128    Nvidia  Windows

# %%
y.sample(3)
# Out:
# 759    10.370823
# 583    11.313402
# 620    11.000210
# Name: Price, dtype: float64

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train.sample(3)
# Out:
#      Company   TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 299     Asus  Ultrabook   16    1.63            0    0  141.211998
# 931       HP  Ultrabook    4    1.26            0    0  176.232574
# 1113      HP  Ultrabook    8    1.16            0    0  165.632118
#
#          Cpu Brands  HDD  SSD Gpu Brand       Os
# 299   Intel Core i7    0  512    Nvidia  Windows
# 931   Intel Core i5  500    0     Intel  Windows
# 1113  Intel Core i7    0  512     Intel  Windows

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# ## Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.807327744841864
# MAE 0.21017827976428802

# %% [markdown]
# ## Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.812733103131181
# MAE 0.20926802242582962

# %% [markdown]
# ## Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8071853945317105
# MAE 0.21114361613472565

# %% [markdown]
# ## KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8017673664034364
# MAE 0.19346118183798544

# %% [markdown]
# ## Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8345104901880461
# MAE 0.18487332756811362

# %% [markdown]
# ## SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8083180902272435
# MAE 0.20239059427315706

# %% [markdown]
# ## Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8873402378382488
# MAE 0.15860130110457718

# %% [markdown]
# ## Extra Trees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=None,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8753793123440623
# MAE 0.15979519126758127

# %% [markdown]
# ## AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.799776702646314
# MAE 0.22831351183448306

# %% [markdown]
# ## Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8827715586124573
# MAE 0.15917780002733048

# %% [markdown]
# ## XgBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8771404806375557
# MAE 0.16262936288951352

# %% [markdown]
# ## Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=None,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8804600180042093
# MAE 0.16525634803678899

# %% [markdown]
# ## Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=None,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=None,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8896248926155927
# MAE 0.156994088085263

# %% [markdown]
# ## Exporting The model

# %%
import pickle

# %%
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
